# %% [markdown]
# <a href="https://www.kaggle.com/code/rohancheera/hello-world?scriptVersionId=143396917" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print(" hello world!!")
